# %%
import pandas as pd
from pathlib import Path
import os

# %%
# Define the base path for data (using current working directory)
base_path = Path(os.getcwd()).parent / "analysis" / "data"

# Define all folder paths to process
folder_paths = [
    # Macro folders
    base_path / "macro" / "macro_no_quality",
    base_path / "macro" / "macro_percentile",
    base_path / "macro" / "macro_q1",
    base_path / "macro" / "macro_q2",
    base_path / "macro" / "macro_q3",
    base_path / "macro" / "macro_q4",
    base_path / "macro" / "macro_quartile",
    # Sub folders
    base_path / "sub" / "sub_no_quality",
    base_path / "sub" / "sub_percentile",
    base_path / "sub" / "sub_q1",
    base_path / "sub" / "sub_q2",
    base_path / "sub" / "sub_q3",
    base_path / "sub" / "sub_q4",
    base_path / "sub" / "sub_quartile",
]

def process_folder(folder_path):
    """
    Process a folder containing rank.txt, labels.csv, and institutions_names.csv files.
    Returns a dataframe with 'area' and 'average' columns.
    
    Structure:
    - Each row in rank.txt corresponds to an area (in order of labels.csv)
    - Each column in rank.txt corresponds to an institution
    - We calculate the average across all institutions for each area
    """
    rank_file = folder_path / "rank.txt"
    labels_file = folder_path / "labels.csv"
    
    if not rank_file.exists() or not labels_file.exists():
        print(f"Warning: Missing files in {folder_path}")
        return None
    
    # Read the files
    # rank.txt contains numeric data (one row per area, one column per institution)
    rank_data = pd.read_csv(rank_file, header=None)
    
    # labels.csv contains the area names (should match number of rows in rank.txt)
    labels_df = pd.read_csv(labels_file, header=None)
    labels = labels_df.iloc[:, 0].tolist()
    
    # Calculate row averages (average across all institutions for each area)
    row_averages = rank_data.mean(axis=1).values
    
    # Create result dataframe
    result_df = pd.DataFrame({
        'area': labels,
        'average': row_averages
    })
    
    return result_df, folder_path.name

# Process all folders
for folder_path in folder_paths:
    if not folder_path.exists():
        print(f"Folder does not exist: {folder_path}")
        continue
    
    result = process_folder(folder_path)
    if result is not None:
        result_df, folder_name = result
        
        # Save to CSV in the same folder
        output_file = folder_path / "averages.csv"
        result_df.to_csv(output_file, index=False)
        print(f"✓ Processed {folder_name}: {len(result_df)} areas")
        print(f"  Saved to: {output_file}")
        print(f"  Sample:\n{result_df.head()}\n")
    else:
        print(f"✗ Failed to process {folder_path.name}\n")

print("Done! All averages have been calculated and saved.")
# Out:
# ✓ Processed macro_no_quality: 27 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\macro\macro_no_quality\averages.csv
#   Sample:
#    area      average
# 0  AGRI  4461.571719
# 1  ARTS   612.875170
# 2  BIOC  1552.100203
# 3  BUSI   387.187146
# 4  CENG   597.834064
#
# ✓ Processed macro_percentile: 27 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\macro\macro_percentile\averages.csv
#   Sample:
#    area       average
# 0  AGRI  25799.198274
# 1  ARTS   2752.956237
# 2  BIOC   9016.880885
# 3  BUSI   2106.236472
# 4  CENG   4053.445077
#
# ✓ Processed macro_q1: 27 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\macro\macro_q1\averages.csv
#   Sample:
#    area      average
# 0  AGRI  1834.196615
# 1  ARTS   159.641682
# 2  BIOC   582.396958
# 3  BUSI   137.263230
# 4  CENG   304.830412
#
# ✓ Processed macro_q2: 27 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\macro\macro_q2\averages.csv
#   Sample:
#    area     average
# 0  AGRI  689.280634
# 1  ARTS  167.053324
# 2  BIOC  437.918735
# 3  BUSI   53.483370
# 4  CENG  173.565876
#
# ✓ Processed macro_q3: 27 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\macro\macro_q3\averages.csv
#   Sample:
#    area     average
# 0  AGRI  524.251223
# 1  ARTS   98.450884
# 2  BIOC  224.010061
# 3  BUSI   47.464934
# 4  CENG   64.912816
#
# ✓ Processed macro_q4: 27 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\macro\macro_q4\averages.csv
#   Sample:
#    area     average
# 0  AGRI  126.887436
# 1  ARTS   38.784954
# 2  BIOC   77.857932
# 3  BUSI   27.083918
# 4  CENG    2.751479
#
# ✓ Processed macro_quartile: 27 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\macro\macro_quartile\averages.csv
#   Sample:
#    area      average
# 0  AGRI  2630.459226
# 1  ARTS   281.022946
# 2  BIOC   929.706983
# 3  BUSI   220.424472
# 4  CENG   420.012475
#
# ✓ Processed sub_no_quality: 333 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\sub\sub_no_quality\averages.csv
#   Sample:
#                                area      average
# 0                      ins_maint_id  6828.150000
# 1                        Accounting    32.813632
# 2         Acoustics and Ultrasonics    56.307495
# 3  Advanced and Specialized Nursing    49.215565
# 4             Aerospace Engineering    45.034201
#
# ✓ Processed sub_percentile: 333 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\sub\sub_percentile\averages.csv
#   Sample:
#                                area      average
# 0                      ins_maint_id  6752.385000
# 1                        Accounting   105.707319
# 2         Acoustics and Ultrasonics   384.165350
# 3  Advanced and Specialized Nursing   255.453161
# 4             Aerospace Engineering   340.912979
#
# ✓ Processed sub_q1: 333 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\sub\sub_q1\averages.csv
#   Sample:
#                                area      average
# 0                      ins_maint_id  6847.665000
# 1                        Accounting     4.825980
# 2         Acoustics and Ultrasonics    35.108658
# 3  Advanced and Specialized Nursing     5.797214
# 4             Aerospace Engineering    31.334220
#
# ✓ Processed sub_q2: 333 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\sub\sub_q2\averages.csv
#   Sample:
#                                area      average
# 0                      ins_maint_id  6679.190000
# 1                        Accounting     1.947276
# 2         Acoustics and Ultrasonics     7.711318
# 3  Advanced and Specialized Nursing    22.655897
# 4             Aerospace Engineering     8.793910
#
# ✓ Processed sub_q3: 333 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\sub\sub_q3\averages.csv
#   Sample:
#                                area      average
# 0                      ins_maint_id  6554.365000
# 1                        Accounting     2.828721
# 2         Acoustics and Ultrasonics     2.614383
# 3  Advanced and Specialized Nursing     3.550860
# 4             Aerospace Engineering     4.324048
#
# ✓ Processed sub_q4: 333 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\sub\sub_q4\averages.csv
#   Sample:
#                                area      average
# 0                      ins_maint_id  6700.560000
# 1                        Accounting     6.261634
# 2         Acoustics and Ultrasonics     1.234522
# 3  Advanced and Specialized Nursing     1.821785
# 4             Aerospace Engineering     0.228906
#
# ✓ Processed sub_quartile: 333 areas
#   Saved to: c:\Users\aline\Desktop\BSCode\Github\Ranking-Interdisciplinaridade\analysis\data\sub\sub_quartile\averages.csv
#   Sample:
#                                area      average
# 0                      ins_maint_id  6828.150000
# 1                        Accounting    12.886244
# 2         Acoustics and Ultrasonics    41.401279
# 3  Advanced and Specialized Nursing    23.600141
# 4             Aerospace Engineering    35.001838
#
# Done! All averages have been calculated and saved.

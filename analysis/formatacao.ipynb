# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import time
from datetime import datetime


import sys
import os

# %%
# MAGIA (não mexer mt pfv)
def show_args(func):
    def wrapper(*args, **kwargs):
        arg_list = []

        # Prepare argument list
        for name, value in zip(func.__code__.co_varnames, args):
            if isinstance(value, pd.DataFrame):
                arg_list.append(f"{name}: DataFrame ({value.shape})")
            else:
                arg_list.append(f"{name}: {value}")
        for k, v in kwargs.items():
            if isinstance(v, pd.DataFrame):
                arg_list.append(f"{k}: DataFrame ({v.shape})")
            else:
                arg_list.append(f"{k}: {v}")

        #print(f"Executando <{func.__name__}>\n({'\\n'.join(arg_list)})")

        # Measure execution time
        start = time.perf_counter()
        result = func(*args, **kwargs)
        end = time.perf_counter()

        print(f"Tempo de execução: {end - start:.6f} segundos\n")
        return result
    return wrapper

# %%
macro_no_quality = pd.read_csv("data/macro/macro_no_quality/sorted_interdis.csv")
macro_quartile = pd.read_csv("data/macro/macro_quartile/sorted_interdis.csv")
sub_no_quality = pd.read_csv("data/sub/sub_no_quality/sorted_interdis.csv")
sub_quartile = pd.read_csv("data/sub/sub_quartile/sorted_interdis.csv")

# %%
plt.figure(figsize=(18, 8))
plt.plot(macro_no_quality['LABEL'].head(20), macro_no_quality['DIV_STAR'].head(20), linestyle=(0, (1, 0)))
plt.xticks(rotation=90, fontsize=15)  # rotate + smaller font
plt.ylabel('Div Star')
plt.title('Ranking Macro Área - Div Star sem qualidade')
plt.grid(True)
plt.savefig("figures/macro_no_quality_div_star.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.plot(macro_quartile['LABEL'].head(20), macro_quartile['DIV_STAR'].head(20), linestyle=(0, (1, 0)))
plt.xticks(rotation=90, fontsize=15)  # rotate + smaller font
plt.ylabel('Div Star')
plt.title('Ranking Macro Área - Div Star com qualidade')
plt.grid(True)
plt.savefig("figures/macro_quartile_div_star.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.plot(sub_no_quality['LABEL'].head(20), sub_no_quality['DIV_STAR'].head(20), linestyle=(0, (1, 0)))
plt.xticks(rotation=90, fontsize=15)  # rotate + smaller font
plt.ylabel('Div Star')
plt.title('Ranking Sub Área - Div Star sem qualidade')
plt.grid(True)
plt.savefig("figures/sub_no_quality_div_star.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.plot(sub_quartile['LABEL'].head(20), sub_quartile['DIV_STAR'].head(20), linestyle=(0, (1, 0)))
plt.xticks(rotation=90, fontsize=15)  # rotate + smaller font
plt.ylabel('Div Star')
plt.title('Ranking Sub Área - Div Star com qualidade')
plt.grid(True)
plt.savefig("figures/sub_quartile_div_star.png", dpi=300, bbox_inches='tight')
plt.show()
